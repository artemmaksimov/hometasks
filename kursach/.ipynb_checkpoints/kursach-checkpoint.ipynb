# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt
from tqdm import tqdm

import pandas as pd
import numpy as np

import statsmodels.formula.api as smf
import statsmodels.tsa.api as smt
import statsmodels.api as sm
import scipy.stats as scs
from scipy.optimize import minimize

import matplotlib.pyplot as plt
import seaborn as sns
import math
import scipy
from statsmodels.tsa.stattools import acf, pacf
from tqdm import tqdm

# %%
air_in = pd.read_excel('04Prioxko-Terrasnyi_774_BZ_aprel_2018.xls')
ai_without_rec = pd.read_excel('04Prioxko-Terrasnyi_774_BZ_aprel_2018.xls')

# %%
air_in = air_in[air_in.YY.notnull()]

# %%
df = air_in
df1 = air_in

# %%
date = []
for i in range(len(df)):
    year = df['YY'].iloc[i]
    if np.isnan(year):
        df1 = df1.drop([i])
        continue
    year = int(year)
    if year >= 83:
        year += 1900
    else:
        year += 2000
    month = int(df['MM'].iloc[i])
    day = int(df['DD'].iloc[i])
    try:
        if day < 10 and month < 10:
            data = np.datetime64(f'{year}-0{month}-0{day}')
        elif day < 10:
            data = np.datetime64(f'{year}-{month}-0{day}')
        elif month < 10:
            data = np.datetime64(f'{year}-0{month}-{day}')
        else:
            data = np.datetime64(f'{year}-{month}-{day}')
    except ValueError:
        df1 = df1.drop([i])
        continue
    date.append(data)

# %%
len(air_in)
# Out:
# 12069

# %%
air_in.drop(labels=5213, inplace=True)

# %%
air_in['date'] = date

# %%
#fill empty columns in air_in
columns = ['TSP', 'SO2', 'SO4', 'NO2']
window = 21
nans = []
for column in columns:
    count = 0    
    s = 0 
    for i in range(len(air_in)):
        if not math.isnan(air_in[column].iloc[i]):
            count += 1
            s += air_in[column].iloc[i]
        else:
            nans.append(i)
        if math.isnan(air_in[column].iloc[i]):
            if count == 0:
                air_in.iloc[i, air_in.columns.get_loc(column)] = 0
            else:
                air_in.iloc[i, air_in.columns.get_loc(column)] = s / count
        if i > window:
            if not ((i - window) in nans):
                count -= 1
                s -= air_in[column].iloc[i - window]

# %%
columns = ['TSP', 'SO2', 'SO4', 'NO2']
for column in columns:
    series = air_in[air_in[column] != 0][column]
    n = 90
    rolling_mean = series.rolling(window=n).mean()

    rolling_std =  series.rolling(window=n).std()
    upper_bond = rolling_mean+1.96*rolling_std

    plt.figure(figsize=(20,10))
    plt.title(column)
    plt.plot(series, label="Actual values")
    plt.plot(rolling_mean, "y", label="Rolling mean trend")

    plt.legend(loc="upper left")
    a = np.polyfit(list(series.index), list(series), deg=1)
    x = list(series.index)
    y = [a[0] * c + a[1] for c in x]
    plt.plot(x, y, color="C1", label='Trend')
    plt.legend(loc='upper left')
    plt.grid(True)
#     plt.savefig(column+'.png')
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-11-f737b74c7fc6> in <module>
#      14
#      15     plt.legend(loc="upper left")
# ---> 16     a = np.polyfit(list(series.index), list(series), deg=1)
#      17     x = list(series.index)
#      18     y = [a[0] * c + a[1] for c in x]
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/polynomial.py in polyfit(x, y, deg, rcond, full, w, cov)
#     626     scale = NX.sqrt((lhs*lhs).sum(axis=0))
#     627     lhs /= scale
# --> 628     c, resids, rank, s = lstsq(lhs, rhs, rcond)
#     629     c = (c.T/scale).T  # broadcast scale coefficients
#     630
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/linalg/linalg.py in lstsq(a, b, rcond)
#    2234         # lapack can't handle n_rhs = 0 - so allocate the array one larger in that axis
#    2235         b = zeros(b.shape[:-2] + (m, n_rhs + 1), dtype=b.dtype)
# -> 2236     x, resids, rank, s = gufunc(a, b, rcond, signature=signature, extobj=extobj)
#    2237     if m == 0:
#    2238         x[...] = 0
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/linalg/linalg.py in _raise_linalgerror_lstsq(err, flag)
#     107
#     108 def _raise_linalgerror_lstsq(err, flag):
# --> 109     raise LinAlgError("SVD did not converge in Linear Least Squares")
#     110
#     111 def get_linalg_error_extobj(callback):
#
# LinAlgError: SVD did not converge in Linear Least Squares

# %%
for column in columns:
    series = air_in[air_in[column] != 0][column]
    print(column + " Критерий Дики-Фуллера: p=%f" % sm.tsa.stattools.adfuller(series)[1])

# %%
for column in columns:
    series = air_in[column].diff()
    n = 60
    rolling_mean = series.rolling(window=n).mean()

    rolling_std =  series.rolling(window=n).std()
    upper_bond = rolling_mean+1.96*rolling_std
    lower_bond = rolling_mean-1.96*rolling_std
    plt.figure(figsize=(20,10))
    plt.title(column+'.diff')
    plt.plot(series, label="Actual values")
    plt.plot(rolling_mean, "y", label="Rolling mean trend")

    plt.plot(upper_bond, "r--", label="Upper Bond")
    plt.plot(lower_bond, "r--", label="Upper Bond")
    plt.legend(loc="upper left")
    plt.grid(True)

# %%
air_in_diff = air_in[columns].diff().dropna()
for column in columns:
    plt.figure(figsize=(10, 5))
    plt.hist(air_in_diff[air_in_diff[column] != 0][column], density=True, bins=100, range = (-50, 50))
    plt.grid(True)

# %%
for column in columns:
    plt.figure(figsize=(10, 5))
    plt.title(column)
    plt.hist(air_in[air_in[column] != 0][column], density=True, bins=50, range = (-50, 50))
    plt.grid(True)
# Out:
# /Users/artemmaksimov/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /Users/artemmaksimov/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
sns.heatmap(air_in.corr(method='pearson'))

# %%
plt.hist(air_in.TSP.dropna().tolist(), density=True, bins=100)
# Out:
# (array([1.56536170e-02, 1.69404094e-02, 2.37985884e-02, 2.08432082e-02,
#         1.91039174e-02, 1.47769013e-02, 1.26275338e-02, 8.14497144e-03,
#         8.24395547e-03, 6.50466469e-03, 4.52498413e-03, 4.04420457e-03,
#         3.13920774e-03, 2.48874127e-03, 1.86655596e-03, 1.59788502e-03,
#         1.25851121e-03, 9.75699704e-04, 8.20153374e-04, 5.65623017e-04,
#         5.37341866e-04, 3.11092659e-04, 3.39373810e-04, 2.82811508e-04,
#         1.55546330e-04, 1.41405754e-04, 1.13124603e-04, 1.13124603e-04,
#         8.48434525e-05, 9.89840279e-05, 5.65623017e-05, 8.48434525e-05,
#         7.07028771e-05, 2.82811508e-05, 0.00000000e+00, 2.82811508e-05,
#         0.00000000e+00, 1.41405754e-05, 0.00000000e+00, 0.00000000e+00,
#         1.41405754e-05, 1.41405754e-05, 2.82811508e-05, 0.00000000e+00,
#         0.00000000e+00, 2.82811508e-05, 2.82811508e-05, 0.00000000e+00,
#         0.00000000e+00, 1.41405754e-05, 1.41405754e-05, 2.82811508e-05,
#         1.41405754e-05, 1.41405754e-05, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 1.41405754e-05, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 1.41405754e-05, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 1.41405754e-05, 1.41405754e-05, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.41405754e-05]),
#  array([  0.  ,   5.86,  11.72,  17.58,  23.44,  29.3 ,  35.16,  41.02,
#          46.88,  52.74,  58.6 ,  64.46,  70.32,  76.18,  82.04,  87.9 ,
#          93.76,  99.62, 105.48, 111.34, 117.2 , 123.06, 128.92, 134.78,
#         140.64, 146.5 , 152.36, 158.22, 164.08, 169.94, 175.8 , 181.66,
#         187.52, 193.38, 199.24, 205.1 , 210.96, 216.82, 222.68, 228.54,
#         234.4 , 240.26, 246.12, 251.98, 257.84, 263.7 , 269.56, 275.42,
#         281.28, 287.14, 293.  , 298.86, 304.72, 310.58, 316.44, 322.3 ,
#         328.16, 334.02, 339.88, 345.74, 351.6 , 357.46, 363.32, 369.18,
#         375.04, 380.9 , 386.76, 392.62, 398.48, 404.34, 410.2 , 416.06,
#         421.92, 427.78, 433.64, 439.5 , 445.36, 451.22, 457.08, 462.94,
#         468.8 , 474.66, 480.52, 486.38, 492.24, 498.1 , 503.96, 509.82,
#         515.68, 521.54, 527.4 , 533.26, 539.12, 544.98, 550.84, 556.7 ,
#         562.56, 568.42, 574.28, 580.14, 586.  ]),
#  <a list of 100 Patch objects>)

# %%
columns = ['TSP', 'SO2', 'SO4', 'NO2']

# %%
for column in columns:
    plt.figure(figsize=(10, 5))
    plt.title(column)
    plt.hist(air_in[air_in[column] != 0][column], density=True, bins=50, range = (-1, 100), cumulative=False)
    plt.grid(True)

# %%
air_in_diff = air_in[columns].diff().dropna()
for column in columns:
    plt.figure(figsize=(10, 5))
    plt.hist(air_in_diff[air_in_diff[column]. != 0][column], density=True, bins=100, range = (-50, 50))
    plt.grid(True)
# Out:
#   File "<ipython-input-17-f0a03934590f>", line 4
#     plt.hist(air_in_diff[air_in_diff[column]. != 0][column], density=True, bins=100, range = (-50, 50))
#                                                ^
# SyntaxError: invalid syntax

# %%
columns = ['TSP', 'SO2', 'SO4', 'NO2']

# %%
for column in columns:
    plt.figure(figsize=(10, 5))
    plt.hist(air_in[column].dropna().diff(), density=True, bins=100 )
    plt.grid(True)

# %%
air_in['TSP'].dropna().diff().describe()
# Out:
# count    12067.000000
# mean         0.001243
# std         22.658385
# min       -441.945455
# 25%         -6.000000
# 50%          0.000000
# 75%          6.112500
# max        484.240000
# Name: TSP, dtype: float64

# %%
from scipy import stats
from scipy.stats import kstest

# %%
kstest(air_in['TSP'].dropna().diff().dropna(), stats.norm.cdf, args=(0,27))
# Out:
# KstestResult(statistic=0.17555824603573789, pvalue=2e-323)

# %%
from sklearn.preprocessing import StandardScaler

# %%
StandardScaler(copy=True, with_mean=True, with_std=True)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
data = np.asarray(air_in['TSP'].dropna().diff().dropna().tolist()).reshape(-1, 1)
scaler = StandardScaler()
scaler.fit(data)
scaler.transform(data)
# Out:
# array([[-5.48631816e-05],
#        [-5.48631816e-05],
#        [-5.48631816e-05],
#        ...,
#        [ 1.45641996e+00],
#        [-1.94202130e+00],
#        [ 2.20623141e-01]])

# %%
plt.figure(figsize=(10, 5))
plt.hist(scaler.transform(data), density=True, bins=30, range = (-3, 3))
plt.grid(True)

# %%
kstest(scaler.transform(data), 'norm')
# Out:
# KstestResult(statistic=1.0, pvalue=0.0)

# %%
columns = ['SO2', 'SO4', 'NO2']
for column in columns:
    plt.figure(figsize=(10, 5))
    plt.hist(air_in[column].dropna().diff(), density=True, bins=30, range = (-20, 20))
    plt.grid(True)
# Out:
# /Users/artemmaksimov/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /Users/artemmaksimov/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
winter_df = air_in[air_in.MM.isin([12.0, 1.0, 2.0])]
spring_df = air_in[air_in.MM.isin([3.0, 4.0, 5.0])]
summer_df = air_in[air_in.MM.isin([6.0, 7.0, 8.0])]
autumn_df = air_in[air_in.MM.isin([9.0, 10.0, 11.0])]

# %%
plt.figure(figsize=(10, 5))
plt.hist(winter_df['TSP'].dropna(), density=True, bins=50)
plt.grid(True)

# %%
plt.figure(figsize=(10, 5))
plt.hist(spring_df['TSP'].dropna(), density=True, bins=50)
plt.grid(True)

# %%
plt.figure(figsize=(10, 5))
plt.hist(summer_df['TSP'].dropna(), density=True, bins=50)
plt.grid(True)

# %%
plt.figure(figsize=(10, 5))
plt.hist(autumn_df['TSP'].dropna(), density=True, bins=60)
plt.grid(True)

# %%
air_in[air_in.TSP >= 100]['MM'].value_counts()
# Out:
# 5.0     146
# 6.0      65
# 4.0      56
# 7.0      36
# 8.0      24
# 9.0      10
# 3.0       9
# 10.0      5
# 11.0      4
# 1.0       3
# 2.0       1
# Name: MM, dtype: int64

# %%
air_in[air_in.TSP >= 300]
# Out:
#          YY   MM    DD   ST   PL   MD   DU     TSP  Q_TSP   SO2  ...  NO2  \
# 1798   89.0  5.0  17.0  4.0  1.0  1.0  1.0  316.00    0.0  0.61  ...  NaN
# 6605    2.0  9.0   8.0  4.0  1.0  1.0  1.0  301.00    0.0  0.05  ...  4.3
# 8325    7.0  5.0  10.0  4.0  1.0  1.0  1.0  300.00    NaN  0.30  ...  4.6
# 9510   10.0  8.0   5.0  4.0  1.0  1.0  1.0  364.00    NaN  0.90  ...  5.8
# 9513   10.0  8.0   8.0  4.0  1.0  1.0  1.0  527.00    NaN  1.30  ...  6.5
# 10172  12.0  5.0  26.0  4.0  1.0  1.0  1.0  306.00    NaN  0.60  ...  5.1
# 10173  12.0  5.0  27.0  4.0  1.0  1.0  1.0  586.00    NaN  0.60  ...  5.4
# 11998  17.0  5.0  24.0  4.0  1.0  1.0  1.0  530.24    NaN  0.30  ...  4.1
# 12118  17.0  9.0  21.0  4.0  1.0  1.0  1.0  411.00    NaN  1.60  ...  4.1
#
#        Q_NO2  NO Q_NO  Примечание с  аэрозол  Unnamed: 25 Unnamed: 26  \
# 1798     NaN NaN  NaN         NaN  0.0300633          NaN         NaN
# 6605     0.0 NaN  NaN  задымление          0          NaN         NaN
# 8325     NaN NaN  NaN         NaN          0          NaN         NaN
# 9510     NaN NaN  NaN         NaN          0          NaN         NaN
# 9513     NaN NaN  NaN         NaN          0          NaN         NaN
# 10172    NaN NaN  NaN         NaN          0          NaN         NaN
# 10173    NaN NaN  NaN         NaN          0          NaN         NaN
# 11998    NaN NaN  NaN         NaN        NaN          NaN         NaN
# 12118    NaN NaN  NaN         NaN        NaN          NaN         NaN
#
#        Unnamed: 27       date
# 1798           NaN 1989-05-17
# 6605           NaN 2002-09-08
# 8325           NaN 2007-05-10
# 9510           NaN 2010-08-05
# 9513           NaN 2010-08-08
# 10172          NaN 2012-05-26
# 10173          NaN 2012-05-27
# 11998          NaN 2017-05-24
# 12118          NaN 2017-09-21
#
# [9 rows x 29 columns]

# %%
from scipy import stats

# %% [markdown]
# # PoVT

# %%
tsp = air_in['TSP'].dropna().tolist()

# %%
s = air_in['TSP'].dropna()

# %%
def get_pareto_data(l, s):
    res = []
    for i in l:
        if i - s > 0:
            res.append(i - s)
    return res

# %%
def get_expon_data(series, s):
    res = []
    series = series[series >= s]
    prev_i = series.index[0]
    for i in list(series.index)[1:]:
        res.append(i - prev_i)
        prev_i = i
    return res

# %%
tsp = air_in['TSP'].dropna().tolist()
tsp_series = air_in['TSP'].dropna()

for s in tqdm(np.linspace(0, max(tsp), num=1000)):
    pareto_data = get_pareto_data(tsp, s)
    expon_data = get_expon_data(tsp_series, s)
    params_pareto = stats.genpareto.fit(pareto_data)
    params_expon = stats.expon.fit(expon_data)
    if stats.kstest(pareto_data, 'genpareto', args=params_pareto).pvalue > 0.01 and stats.kstest(expon_data, 'expon', args=params_expon).pvalue > 0.01:
        povt = s
        pvalue_pareto = stats.kstest(pareto_data, 'genpareto', args=params).pvalue
        pvalue_expon = stats.kstest(expon_data, 'expon', args=params_expon).pvalue 
        break
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]/Users/artemmaksimov/anaconda3/lib/python3.7/site-packages/scipy/stats/_continuous_distns.py:2248: RuntimeWarning: divide by zero encountered in true_divide
#   val = val + cnk * (-1) ** ki / (1.0 - c * ki)
# /Users/artemmaksimov/anaconda3/lib/python3.7/site-packages/scipy/stats/_distn_infrastructure.py:1035: RuntimeWarning: invalid value encountered in subtract
#   mu2 = mu2p - mu * mu
# /Users/artemmaksimov/anaconda3/lib/python3.7/site-packages/scipy/stats/_distn_infrastructure.py:2316: RuntimeWarning: invalid value encountered in double_scalars
#   Lhat = muhat - Shat*mu
#  42%|████▏     | 416/1000 [01:05<01:08,  8.57it/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-9a81096eb389> in <module>
#       9     if stats.kstest(pareto_data, 'genpareto', args=params_pareto).pvalue > 0.01 and stats.kstest(expon_data, 'expon', args=params_expon).pvalue > 0.01:
#      10         povt = s
# ---> 11         pvalue_pareto = stats.kstest(pot(tsp, povt), 'genpareto', args=params).pvalue
#      12         pvalue_expon = stats.kstest(expon_data, 'expon', args=params_expon).pvalue
#      13         break
#
# NameError: name 'pot' is not defined

# %%
povt
# Out:
# 244.02002002002

# %%
pvalue_pareto = stats.kstest(pareto_data, 'genpareto', args=params_pareto).pvalue
pvalue_expon = stats.kstest(expon_data, 'expon', args=params_expon).pvalue

# %%
air_in[air_in.TSP > povt].MM.value_counts()
# Out:
# 5.0     6
# 8.0     3
# 4.0     3
# 9.0     2
# 11.0    2
# 7.0     1
# Name: MM, dtype: int64

# %%
column = 'TSP'
series = air_in[air_in[column] != 0][column]
n = 90
rolling_mean = series.rolling(window=n).mean()

rolling_std =  series.rolling(window=n).std()
upper_bond = rolling_mean+1.96*rolling_std

plt.figure(figsize=(20,10))
plt.title(column)
plt.plot(series, label="Actual values")
plt.plot(rolling_mean, "y", label="Rolling mean trend")

plt.legend(loc="upper left")
a = np.polyfit(list(series.index), list(series), deg=1)
x = list(series.index)
y = [a[0] * c + a[1] for c in x]
plt.plot(x, y, color="C1", label='Trend')
y = [povt for c in x]
plt.plot(x, y, color="red", label='PoVT')
plt.legend(loc='upper left')
plt.grid(True)

# %%
a[0]
# Out:
# -7.630371478306367e-05

# %%
real_tsp = ai_without_rec['TSP'].dropna()

# %%
def get_year(y):
    if y <= 17:
        return y + 2000
    else:
        return y + 1900
    
    
ai_without_rec['year'] =  ai_without_rec['YY'].apply(get_year)

# %%
for year in ai_without_rec['year'].dropna().unique().tolist():
    print(year)
    series = ai_without_rec[ai_without_rec.year >= year]['TSP'].dropna()
    a = np.polyfit(list(series.index), list(series), deg=1)
    print(a[0], a[1], '\n')
# Out:
# 1983.0
# -0.0003041014697583281 37.61134648500678
#
# 1984.0
# -0.0003041014697583281 37.61134648500678
#
# 1985.0
# -0.0003041014697583281 37.61134648500678
#
# 1986.0
# -0.00017382925377699808 36.6180046030462
#
# 1987.0
# 2.0530879810717178e-05 35.10279895700086
#
# 1988.0
# 0.0003067555895805624 32.82208929216913
#
# 1989.0
# 0.000808106943879429 28.743302056620642
#
# 1990.0
# 0.0012447102885559608 25.1074624651831
#
# 1991.0
# 0.0013491981715730399 24.220774540297892
#
# 1992.0
# 0.001572770958676482 22.281237819348412
#
# 1993.0
# 0.0019869024344684274 18.605469371243995
#
# 1994.0
# 0.0023458238896731905 15.36083724114069
#
# 1995.0
# 0.002952852942529971 9.770072556890609
#
# 1996.0
# 0.0036967764670177497 2.811685010282397
#
# 1997.0
# 0.004369987707836204 -3.597148696051618
#
# 1998.0
# 0.004693977280878698 -6.725488276542825
#
# 1999.0
# 0.004856421828111687 -8.311400129646106
#
# 2000.0
# 0.005129330459847112 -11.011420853341958
#
# 2001.0
# 0.005320395655570781 -12.919869451430024
#
# 2002.0
# 0.005707382799058131 -16.849124397670607
#
# 2003.0
# 0.006303788148918932 -22.969864809080846
#
# 2004.0
# 0.0069572042960337616 -29.762680867559006
#
# 2005.0
# 0.006599307028607717 -25.98053302705675
#
# 2006.0
# 0.006361661586667005 -23.43865878441292
#
# 2007.0
# 0.005411174301803862 -13.204572667235162
#
# 2008.0
# 0.002671405219743406 16.65848045274388
#
# 2009.0
# -0.0011038353439950732 58.202993242877994
#
# 2010.0
# -0.008339588173380671 138.78071159470184
#
# 2011.0
# -0.0021048666723204584 68.6470040453701
#
# 2012.0
# -0.0015980878257528424 62.83644693684984
#
# 2013.0
# 0.000829095350928719 35.04798641126167
#
# 2014.0
# 0.002308622555493503 17.987886265253213
#
# 2015.0
# -0.0032609775425064213 83.45786992394237
#
# 2016.0
# 0.01999811369715787 -193.12282318663955
#
# 2017.0
# 0.13390661207192114 -1559.0936121451862

# %%
ai_without_rec['year'].dropna().unique().tolist()
# Out:
# [1983.0,
#  1984.0,
#  1985.0,
#  1986.0,
#  1987.0,
#  1988.0,
#  1989.0,
#  1990.0,
#  1991.0,
#  1992.0,
#  1993.0,
#  1994.0,
#  1995.0,
#  1996.0,
#  1997.0,
#  1998.0,
#  1999.0,
#  2000.0,
#  2001.0,
#  2002.0,
#  2003.0,
#  2004.0,
#  2005.0,
#  2006.0,
#  2007.0,
#  2008.0,
#  2009.0,
#  2010.0,
#  2011.0,
#  2012.0,
#  2013.0,
#  2014.0,
#  2015.0,
#  2016.0,
#  2017.0]
